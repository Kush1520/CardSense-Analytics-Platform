# %%
import os

print(os.listdir("../data"))
# Out:
# ['.DS_Store', 'merchant_master.csv', 'customer360.csv', 'creditcard.csv', 'online_retail_II.xlsx', 'customer360_enriched.csv', 'bank+marketing', 'processed', 'engagement.csv', 'marketing_campaign.csv', 'BankChurners.csv']

# %%
import pandas as pd

fraud = pd.read_csv("../data/processed/fraud_clean.csv")

print(fraud.shape)
# Out:
# (284807, 31)

# %%
part1 = fraud.iloc[:150000]
part2 = fraud.iloc[150000:]

part1.to_csv(
    "../data/fraud_part1.csv",
    index=False
)

part2.to_csv(
    "../data/fraud_part2.csv",
    index=False
)

print(part1.shape)
print(part2.shape)
# Out:
# (150000, 31)
# (134807, 31)
